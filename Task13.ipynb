# %% [markdown]
# <a href="https://colab.research.google.com/github/jeeva477/DL_Skill_Tracker/blob/main/Task13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TASK 13: Attention Mechanisms

import torch
import torch.nn as nn
import torch.nn.functional as F

class Attention(nn.Module):
    def __init__(self, d_model=20):
        super().__init__()
        self.q = nn.Linear(d_model, d_model)
        self.k = nn.Linear(d_model, d_model)
        self.v = nn.Linear(d_model, d_model)

    def forward(self, x):
        Q, K, V = self.q(x), self.k(x), self.v(x)
        scores = torch.matmul(Q, K.transpose(-2, -1)) / (20 ** 0.5)
        weights = F.softmax(scores, dim=-1)
        return torch.matmul(weights, V)

attention = Attention()
x = torch.randn(4, 1, 20)
output = attention(x)

print("Input :", x.shape)
print("Output:", output.shape)
# Out:
# Input : torch.Size([4, 1, 20])
# Output: torch.Size([4, 1, 20])
